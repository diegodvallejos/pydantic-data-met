# %%
import requests
from rich import print

def get_data():
    response = requests.get("https://www.allbirds.co.uk/products.json")
    return response.json()['products']

# %%
data = get_data()

# %%
data
# Out:
# [{'id': 7208137425028,
#   'title': "Women's Tree Runners - Light Grey (Light Grey Sole)",
#   'handle': 'womens-tree-runners-light-grey',
#   'body_html': '<p>The Allbirds Tree Runner is a breathable and lightweight sneaker made with responsibly sourced eucalyptus tree fibre that feels silky smooth and cool on your skin. These shoes are perfect for everyday casual wear, walking, and warmer weather.</p>',
#   'published_at': '2024-04-19T06:39:18+01:00',
#   'created_at': '2023-12-14T21:03:16+00:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 4.99',
#    'allbirds::cfId => color-womens-tree-runners-light-grey-light-grey',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => womens',
#    'allbirds::hue => grey',
#    'allbirds::master => womens-tree-runners',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => runner',
#    'allbirdskit::kit-discount-69llI09wAImGAsGtS9wOgp => 0',
#    'allbirdskit::kit-id => 69llI09wAImGAsGtS9wOgp',
#    'allbirdskit::kit-size-69llI09wAImGAsGtS9wOgp => 2',
#    'loop::returnable => true',
#    'YCRF_womens-move-shoes',
#    'YGroup_ygroup_womens-tree-runners'],
#   'variants': [{'id': 41691906769028,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 725,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906801796,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 751,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906834564,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 777,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906867332,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 834,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906900100,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 860,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906932868,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 886,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691906965636,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10659W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 951,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7208137425028,
#     'created_at': '2023-12-14T21:03:16+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 34356885422212,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 1,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_4_09fd7ca5-57f5-46de-b2af-d6310c710031.png?v=1712006740',
#     'width': 1110,
#     'height': 1110},
#    {'id': 34356885454980,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 2,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/24Q1-Spring-Ch1-Site-PDP-TR-W-Desktop-1600x1600_b2d27c09-d2dc-4f81-b3f5-e55a56834878.jpg?v=1712006740',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34356885487748,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 3,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_dc1d6e01-2b7f-47db-a8af-fc358f8a0eaa.png?v=1712006740',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356885520516,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 4,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_5_52a67391-72d1-41db-9897-18e83739b9fe.png?v=1712006740',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356885553284,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 5,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_2_2d46eabe-1b86-43f9-a556-8221fbfac44f.png?v=1712006740',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356885586052,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 6,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_1_7b134ca6-9cf8-47e4-81bb-cd8ba37e0322.png?v=1712006740',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356885618820,
#     'created_at': '2024-04-01T22:25:40+01:00',
#     'position': 7,
#     'updated_at': '2024-04-01T22:25:40+01:00',
#     'product_id': 7208137425028,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10658_Tree_Runner_Mens_Light_Grey_Light_Grey_3_73de016c-d736-4dde-a84a-0e50a3e2c45e.png?v=1712006740',
#     'width': 2400,
#     'height': 2400}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2', 'UK 3', 'UK 4', 'UK 5', 'UK 6', 'UK 7', 'UK 8']}]},
#  {'id': 7188697579652,
#   'title': "Women's Tree Runners - Rugged Beige (Natural White Sole)",
#   'handle': 'womens-tree-runners-rugged-beige',
#   'body_html': '<p>The Allbirds Tree Runner is a breathable and lightweight sneaker made with responsibly sourced eucalyptus tree fibre that feels silky smooth and cool on your skin. These shoes are perfect for everyday casual wear, walking, and warmer weather.</p>',
#   'published_at': '2024-04-19T06:38:01+01:00',
#   'created_at': '2023-10-21T07:01:13+01:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 4.99',
#    'allbirds::cfId => color-womens-tree-runners-rugged-beige-ntrl-wht',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => womens',
#    'allbirds::hue => beige',
#    'allbirds::master => womens-tree-runners',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => runner',
#    'allbirdskit::kit-discount-69llI09wAImGAsGtS9wOgp => 0',
#    'allbirdskit::kit-id => 69llI09wAImGAsGtS9wOgp',
#    'allbirdskit::kit-size-69llI09wAImGAsGtS9wOgp => 2',
#    'loop::returnable => true',
#    'YCRF_womens-move-shoes',
#    'YGroup_ygroup_womens-tree-runners'],
#   'variants': [{'id': 41637865029764,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 725,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:13+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865062532,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 751,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:13+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865095300,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 777,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:14+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865128068,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 834,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:14+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865160836,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 860,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:14+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865193604,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 886,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:14+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41637865226372,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10785W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 951,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7188697579652,
#     'created_at': '2023-10-21T07:01:14+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 34356884439172,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 1,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_1_0815136e-4628-4e35-b1fa-4523bcb2fc93.png?v=1712006733',
#     'width': 1110,
#     'height': 1110},
#    {'id': 34356884471940,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 2,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/24Q1-Spring-Ch1-Site-PDP-TR-W-Desktop-1600x1600_b870380b-1213-4905-a421-3aca091add70.jpg?v=1712006733',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34356884504708,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 3,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_5_835c428f-6661-4570-a579-091496d69872.png?v=1712006733',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356884537476,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 4,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_4_0a853806-a0cb-4397-a5fd-2342aefac37e.png?v=1712006733',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356884570244,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 5,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_6b0cbe3f-008c-4d2a-9a20-3f67609e7cba.png?v=1712006733',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356884603012,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 6,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_2_3968f80a-3cc1-42b7-824c-4aee62270f38.png?v=1712006733',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356884668548,
#     'created_at': '2024-04-01T22:25:33+01:00',
#     'position': 7,
#     'updated_at': '2024-04-01T22:25:33+01:00',
#     'product_id': 7188697579652,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10788_Tree_Runner_Mens_Rugged_Beige_Natural_White_3_6de42501-15e8-4090-80bb-e093c8ca2833.png?v=1712006733',
#     'width': 2400,
#     'height': 2400}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2', 'UK 3', 'UK 4', 'UK 5', 'UK 6', 'UK 7', 'UK 8']}]},
#  {'id': 7172141613188,
#   'title': "Women's Wool Dasher Mizzles - Natural Black (Bark Grey Sole)",
#   'handle': 'womens-wool-dasher-mizzles-natural-black-bark-grey',
#   'body_html': '<p>The Wool Dasher Mizzle is a running shoe that uses natural materials to give you extra grip and keep your feet cosy and dry on cold, wet runs.</p>',
#   'published_at': '2024-04-15T09:47:16+01:00',
#   'created_at': '2023-09-22T22:49:10+01:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 8.18',
#    'allbirds::cfId => color-womens-wool-dasher-mizzles-natural-black-bark-grey',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => womens',
#    'allbirds::hue => black',
#    'allbirds::hue => green',
#    'allbirds::master => womens-wool-dasher-mizzles',
#    'allbirds::material => wool',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => dasher',
#    'loop::returnable => true',
#    'YCRF_womens-perform-shoes',
#    'YGroup_ygroup_womens-wool-dasher-mizzles'],
#   'variants': [{'id': 41603355639940,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 880,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355672708,
#     'title': 'UK 2.5',
#     'option1': 'UK 2.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W055',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 893,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355705476,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 900,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355738244,
#     'title': 'UK 3.5',
#     'option1': 'UK 3.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W065',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 917,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355771012,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 946,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355803780,
#     'title': 'UK 4.5',
#     'option1': 'UK 4.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W075',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '135.00',
#     'grams': 980,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355836548,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '135.00',
#     'grams': 989,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:10+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355869316,
#     'title': 'UK 5.5',
#     'option1': 'UK 5.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W085',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 1013,
#     'compare_at_price': None,
#     'position': 8,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355902084,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 1020,
#     'compare_at_price': None,
#     'position': 9,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355934852,
#     'title': 'UK 6.5',
#     'option1': 'UK 6.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W095',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '135.00',
#     'grams': 1045,
#     'compare_at_price': None,
#     'position': 10,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603355967620,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '135.00',
#     'grams': 1055,
#     'compare_at_price': None,
#     'position': 11,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603356000388,
#     'title': 'UK 7.5',
#     'option1': 'UK 7.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W105',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '135.00',
#     'grams': 1115,
#     'compare_at_price': None,
#     'position': 12,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41603356033156,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10189W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '135.00',
#     'grams': 1138,
#     'compare_at_price': None,
#     'position': 13,
#     'product_id': 7172141613188,
#     'created_at': '2023-09-22T22:49:11+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 33377924579460,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 1,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-45-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_eda6a274-5dd1-4710-84b4-c392ea4bb610.png?v=1696278628',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33377924612228,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 2,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/WDM-Lifestyle-PDP-Female-1_c99f322a-3326-4168-a167-f8cceea8bed8.jpg?v=1696278628',
#     'width': 1000,
#     'height': 1000},
#    {'id': 33377924644996,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 3,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-Side-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_bf7a58f2-eb5f-49c6-a3ef-dccecd5e1d88.png?v=1696278628',
#     'width': 1110,
#     'height': 1110},
#    {'id': 33377924677764,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 4,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-Heel-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_7c8f1fe4-63d8-43c9-8c06-69865b3043c7.png?v=1696278628',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33377924710532,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 5,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-Top-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_38e7d197-14a8-4be4-8dc0-4c6877a957d7.png?v=1696278628',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33377924743300,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 6,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-Bottom-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_5fc59452-28af-4bb3-99d4-f2f82263d8e2.png?v=1696278628',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33377924776068,
#     'created_at': '2023-10-02T21:30:28+01:00',
#     'position': 7,
#     'updated_at': '2023-10-02T21:30:28+01:00',
#     'product_id': 7172141613188,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10189M100-Wool_Dasher_2_Mizzle-Pair-Global-Womens-Wool-Natural_Black-Bark_Grey-CF1_9c80ddd0-c12e-4f38-87c3-869b72a7ec66.png?v=1696278628',
#     'width': 1600,
#     'height': 1600}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2',
#      'UK 2.5',
#      'UK 3',
#      'UK 3.5',
#      'UK 4',
#      'UK 4.5',
#      'UK 5',
#      'UK 5.5',
#      'UK 6',
#      'UK 6.5',
#      'UK 7',
#      'UK 7.5',
#      'UK 8']}]},
#  {'id': 7100328444036,
#   'title': "Women's Tree Pipers - Natural Black (Blizzard Sole)",
#   'handle': 'womens-tree-pipers-natural-black',
#   'body_html': "<p>The Tree Piper is a classic low-top silhouette that's been reimagined for everyday casual wear while walking in warmer weather. It's made with lightweight, breathable, and comfortable natural materials, and is all about balancing simplicity and exaggeration for versatile styling.</p>",
#   'published_at': '2024-04-15T09:46:47+01:00',
#   'created_at': '2023-04-14T01:51:03+01:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 5.31',
#    'allbirds::cfId => color-womens-tree-pipers-natural-black-blizzard',
#    'allbirds::complete => true',
#    'allbirds::edition => classic',
#    'allbirds::gender => womens',
#    'allbirds::hue => black',
#    'allbirds::master => womens-tree-pipers',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => piper',
#    'loop::returnable => true',
#    'YCRF_womens-move-shoes',
#    'YGroup_ygroup_womens-tree-pipers'],
#   'variants': [{'id': 41391104950404,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1560,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391104983172,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1560,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391105015940,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1560,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391105048708,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1560,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391105081476,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1530,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391105114244,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1530,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41391105147012,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'AB00E6W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '105.00',
#     'grams': 1530,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7100328444036,
#     'created_at': '2023-04-14T01:51:04+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 34238205165700,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 1,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_45_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_1908d081-87fc-4af6-bacc-6b9946047574.png?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205198468,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 2,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/24Q1-Spring-Ch2-Site-PDP-TP-W-Desktop-1600x1600_15bbbb5a-f16e-403b-8d92-493b672fac64.jpg?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205231236,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 3,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_PROFILE_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_fe9c9105-52e5-44a9-9e00-9300a28ab1bd.png?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205264004,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 4,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_HEEL_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_7c5c1782-e63e-4d00-b764-ebfe5e4c7d04.png?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205296772,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 5,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_OVERHEAD_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_09e21eb1-8809-4c56-8cf4-38e8315d2992.png?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205329540,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 6,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_BOTTOM_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_4d348fe8-0303-48e6-93a9-620a68aa2b6c.png?v=1709668979',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34238205362308,
#     'created_at': '2024-03-05T20:02:59+00:00',
#     'position': 7,
#     'updated_at': '2024-03-05T20:02:59+00:00',
#     'product_id': 7100328444036,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/AB00E6W090_SHOE_PAIR_GLOBAL_MENS_TREE_PIPER_NATURAL_BLACK_BLIZZARD_00023b80-2a15-4cda-9c40-a30a3d1877da.png?v=1709668979',
#     'width': 1600,
#     'height': 1600}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2', 'UK 3', 'UK 4', 'UK 5', 'UK 6', 'UK 7', 'UK 8']}]},
#  {'id': 7124328677508,
#   'title': "Women's Couriers - Blizzard (Natural White Sole)",
#   'handle': 'womens-couriers-blizzard',
#   'body_html': '<p>Our nod to a vintage trainer made with natural materials for a better future. The retro silhouette elevated with intricate details pairs with anything you have planned. Come for the throwback style, and stay for the cushy all-day-wearability.</p>',
#   'published_at': '2024-04-15T09:45:11+01:00',
#   'created_at': '2023-06-27T17:13:51+01:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 5.51',
#    'allbirds::cfId => color-womens-couriers-blizzard-natural-white',
#    'allbirds::complete => true',
#    'allbirds::edition => classic',
#    'allbirds::gender => womens',
#    'allbirds::hue => white',
#    'allbirds::master => womens-couriers',
#    'allbirds::material => cotton',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => runner',
#    'loop::returnable => true',
#    'YCRF_womens-move-shoes',
#    'YGroup_ygroup_womens-couriers'],
#   'variants': [{'id': 41465039093892,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 800,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039126660,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 830,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039159428,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 860,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039192196,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 890,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039224964,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 970,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039257732,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 1001,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41465039290500,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10041W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '115.00',
#     'grams': 1040,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7124328677508,
#     'created_at': '2023-06-27T17:13:51+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 33149244801156,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 1,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_45_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_0f2abf2d-aa79-414e-860d-503b24892a2c.png?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244833924,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 2,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/23Q3_SNS_PDP-GRID-01_Courier-W.jpg?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244866692,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 3,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_PROFILE_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_fd19e706-3999-473a-a745-de4746fb2a71.png?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244899460,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 4,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_HEEL_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_ecacfbe2-f056-4348-bfcf-457bc8c0f3ec.png?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244932228,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 5,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_OVERHEAD_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_18073c02-e4d0-42b5-b192-755549d3a441.png?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244964996,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 6,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_BOTTOM_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_20b6133b-4eea-41ed-a0db-4aba05a9f14d.png?v=1692393255',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33149244997764,
#     'created_at': '2023-08-18T22:14:15+01:00',
#     'position': 7,
#     'updated_at': '2023-08-18T22:14:15+01:00',
#     'product_id': 7124328677508,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/SKU_SHOE_PAIR_GLOBAL_WOMENS_COURIER_BLIZZARD_NATURAL_WHITE_de7d996f-2232-4dd5-8817-a03ce9a05796.png?v=1692393255',
#     'width': 1600,
#     'height': 1600}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2', 'UK 3', 'UK 4', 'UK 5', 'UK 6', 'UK 7', 'UK 8']}]},
#  {'id': 7123331547268,
#   'title': "Men's Tree Flyer 2 - Natural Black, Hazy Indigo (Swift Grey Sole)",
#   'handle': 'mens-tree-flyers-natural-black-hazy-indigo',
#   'body_html': '<p>Bring the fun to any run with the Tree Flyer 2. The seriously springy (and seriously sustainable) running shoe you love is back with increased stability, support, and grip to keep those smiles coming kilometre after kilometre.</p>',
#   'published_at': '2024-04-15T09:43:40+01:00',
#   'created_at': '2023-06-22T19:40:55+01:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 7.21',
#    'allbirds::cfId => color-mens-tree-flyer2-ntl-blk-hz-ind-swt-gry',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => mens',
#    'allbirds::hue => black',
#    'allbirds::hue => blue',
#    'allbirds::hue => grey',
#    'allbirds::master => mens-tree-flyers',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => dasher',
#    'loop::returnable => true',
#    'YCRF_mens-perform-shoes',
#    'YGroup_ygroup_mens-tree-flyers'],
#   'variants': [{'id': 41458906824836,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 928,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458906890372,
#     'title': 'UK 7.5',
#     'option1': 'UK 7.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M085',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 976,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458906988676,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 994,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907054212,
#     'title': 'UK 8.5',
#     'option1': 'UK 8.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M095',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1012,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907152516,
#     'title': 'UK 9',
#     'option1': 'UK 9',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1030,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907250820,
#     'title': 'UK 9.5',
#     'option1': 'UK 9.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M105',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1048,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907349124,
#     'title': 'UK 10',
#     'option1': 'UK 10',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '150.00',
#     'grams': 1066,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907447428,
#     'title': 'UK 10.5',
#     'option1': 'UK 10.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M115',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1246,
#     'compare_at_price': None,
#     'position': 8,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907578500,
#     'title': 'UK 11',
#     'option1': 'UK 11',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M120',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': False,
#     'price': '150.00',
#     'grams': 1260,
#     'compare_at_price': None,
#     'position': 9,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907709572,
#     'title': 'UK 11.5',
#     'option1': 'UK 11.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M125',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1290,
#     'compare_at_price': None,
#     'position': 10,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907807876,
#     'title': 'UK 12',
#     'option1': 'UK 12',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M130',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1300,
#     'compare_at_price': None,
#     'position': 11,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458907906180,
#     'title': 'UK 12.5',
#     'option1': 'UK 12.5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M135',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1318,
#     'compare_at_price': None,
#     'position': 12,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41458908037252,
#     'title': 'UK 13',
#     'option1': 'UK 13',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10034M140',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '150.00',
#     'grams': 1334,
#     'compare_at_price': None,
#     'position': 13,
#     'product_id': 7123331547268,
#     'created_at': '2023-06-22T19:40:55+01:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 33010185896068,
#     'created_at': '2023-07-20T00:20:02+01:00',
#     'position': 1,
#     'updated_at': '2023-07-20T00:20:02+01:00',
#     'product_id': 7123331547268,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/products/A10036W090_SHOE_45_GLOBAL_WOMENS_TREE_FLYER_2_NATURAL_BLACK_HAZY_INDIGO_SWIFT_GREY.png?v=1689808802',
#     'width': 1600,
#     'height': 1600},
#    {'id': 33010185928836,
#     'created_at': '2023-07-20T00:20:02+01:00',
#     'position': 2,
#     'updated_at': '2023-07-20T00:20:02+01:00',
#     'product_id': 7123331547268,
#     'variant_ids': [],
# ...
#     'width': 2400,
#     'height': 2400},
#    {'id': 34320370139268,
#     'created_at': '2024-03-22T23:31:08+00:00',
#     'position': 5,
#     'updated_at': '2024-03-22T23:31:08+00:00',
#     'product_id': 7208149024900,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10731_Tree_Lounger_Rugged_Beige_Rugged_Beige.png?v=1711150268',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34320370172036,
#     'created_at': '2024-03-22T23:31:08+00:00',
#     'position': 6,
#     'updated_at': '2024-03-22T23:31:08+00:00',
#     'product_id': 7208149024900,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10731_Tree_Lounger_Rugged_Beige_Rugged_Beige_4.png?v=1711150268',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34320370204804,
#     'created_at': '2024-03-22T23:31:08+00:00',
#     'position': 7,
#     'updated_at': '2024-03-22T23:31:08+00:00',
#     'product_id': 7208149024900,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10731_Tree_Lounger_Rugged_Beige_Rugged_Beige_1.png?v=1711150268',
#     'width': 2400,
#     'height': 2400}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 7', 'UK 8', 'UK 9', 'UK 10', 'UK 11', 'UK 12', 'UK 13']}]},
#  {'id': 7208137064580,
#   'title': "Women's Tree Runners - Rugged Green (Blizzard Sole)",
#   'handle': 'womens-tree-runners-rugged-green',
#   'body_html': '<p>The Allbirds Tree Runner is a breathable and lightweight sneaker made with responsibly sourced eucalyptus tree fibre that feels silky smooth and cool on your skin. These shoes are perfect for everyday casual wear, walking, and warmer weather.</p>',
#   'published_at': '2024-03-18T17:10:46+00:00',
#   'created_at': '2023-12-14T21:01:25+00:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 4.99',
#    'allbirds::cfId => color-womens-tree-runners-rugged-green-blizzard',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => womens',
#    'allbirds::hue => green',
#    'allbirds::master => womens-tree-runners',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => runner',
#    'allbirdskit::kit-discount-69llI09wAImGAsGtS9wOgp => 0',
#    'allbirdskit::kit-id => 69llI09wAImGAsGtS9wOgp',
#    'allbirdskit::kit-size-69llI09wAImGAsGtS9wOgp => 2',
#    'loop::returnable => true',
#    'YCRF_womens-move-shoes',
#    'YGroup_ygroup_womens-tree-runners'],
#   'variants': [{'id': 41691905196164,
#     'title': 'UK 2',
#     'option1': 'UK 2',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W050',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 725,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905228932,
#     'title': 'UK 3',
#     'option1': 'UK 3',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W060',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 751,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905261700,
#     'title': 'UK 4',
#     'option1': 'UK 4',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W070',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 777,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905294468,
#     'title': 'UK 5',
#     'option1': 'UK 5',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 834,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905327236,
#     'title': 'UK 6',
#     'option1': 'UK 6',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 860,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905360004,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 886,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691905392772,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10661W110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 951,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7208137064580,
#     'created_at': '2023-12-14T21:01:25+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 34356889616516,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 1,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_3_a21c6318-26e9-48e6-91a0-007328210ac3.png?v=1712006775',
#     'width': 1110,
#     'height': 1110},
#    {'id': 34356889649284,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 2,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/24Q1-Spring-Ch1-Site-PDP-TR-W-Desktop-1600x1600.jpg?v=1712006775',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34356889682052,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 3,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_4_22954591-47ab-49ba-9256-9490a47bb84f.png?v=1712006775',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356889714820,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 4,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_1_9321783c-46c2-4402-ac14-c922cebba5ac.png?v=1712006775',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356889747588,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 5,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_5_2e095cec-5683-4ede-952d-0a840c577097.png?v=1712006775',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356889780356,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 6,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_2_19ac3598-3c0a-4ab2-9d51-0833247d8108.png?v=1712006775',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356889813124,
#     'created_at': '2024-04-01T22:26:15+01:00',
#     'position': 7,
#     'updated_at': '2024-04-01T22:26:15+01:00',
#     'product_id': 7208137064580,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_af8de951-9356-46f0-a2cc-4924f84f64e6.png?v=1712006775',
#     'width': 2400,
#     'height': 2400}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 2', 'UK 3', 'UK 4', 'UK 5', 'UK 6', 'UK 7', 'UK 8']}]},
#  {'id': 7208148664452,
#   'title': "Men's Tree Runners - Rugged Green (Blizzard Sole)",
#   'handle': 'mens-tree-runners-rugged-green',
#   'body_html': '<p>The Allbirds Tree Runner is a breathable and lightweight trainer made with responsibly sourced eucalyptus tree fiber that feels silky smooth and cool on your skin. These shoes are perfect for everyday casual wear, walking, and warmer weather.</p>',
#   'published_at': '2024-03-18T17:10:28+00:00',
#   'created_at': '2023-12-14T21:41:33+00:00',
#   'updated_at': '2024-04-19T16:53:05+01:00',
#   'vendor': 'Allbirds',
#   'product_type': 'Shoes',
#   'tags': ['allbirds::carbon-score => 4.99',
#    'allbirds::cfId => color-mens-tree-runners-rugged-green-blizzard',
#    'allbirds::complete => true',
#    'allbirds::edition => limited',
#    'allbirds::gender => mens',
#    'allbirds::hue => green',
#    'allbirds::master => mens-tree-runners',
#    'allbirds::material => tree',
#    'allbirds::price-tier => msrp',
#    'allbirds::silhouette => runner',
#    'allbirdskit::kit-discount-2pPynpFQ2oCKNjoEN1KjVb => 0',
#    'allbirdskit::kit-id => 2pPynpFQ2oCKNjoEN1KjVb',
#    'allbirdskit::kit-size-2pPynpFQ2oCKNjoEN1KjVb => 2',
#    'loop::returnable => true',
#    'YCRF_mens-move-shoes',
#    'YGroup_ygroup_mens-tree-runners'],
#   'variants': [{'id': 41691943305348,
#     'title': 'UK 7',
#     'option1': 'UK 7',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M080',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 1,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943338116,
#     'title': 'UK 8',
#     'option1': 'UK 8',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M090',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 2,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943370884,
#     'title': 'UK 9',
#     'option1': 'UK 9',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M100',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 3,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943403652,
#     'title': 'UK 10',
#     'option1': 'UK 10',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M110',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 4,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943436420,
#     'title': 'UK 11',
#     'option1': 'UK 11',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M120',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 5,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943469188,
#     'title': 'UK 12',
#     'option1': 'UK 12',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M130',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 6,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'},
#    {'id': 41691943501956,
#     'title': 'UK 13',
#     'option1': 'UK 13',
#     'option2': None,
#     'option3': None,
#     'sku': 'A10660M140',
#     'requires_shipping': True,
#     'taxable': True,
#     'featured_image': None,
#     'available': True,
#     'price': '110.00',
#     'grams': 1000,
#     'compare_at_price': None,
#     'position': 7,
#     'product_id': 7208148664452,
#     'created_at': '2023-12-14T21:41:33+00:00',
#     'updated_at': '2024-04-19T16:53:05+01:00'}],
#   'images': [{'id': 34356885946500,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 1,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_3.png?v=1712006748',
#     'width': 1110,
#     'height': 1110},
#    {'id': 34356885979268,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 2,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/24Q1-Spring-Ch1-Site-PDP-TR-M-Desktop-1600x1600.jpg?v=1712006748',
#     'width': 1600,
#     'height': 1600},
#    {'id': 34356886012036,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 3,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_4.png?v=1712006748',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356886044804,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 4,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_1.png?v=1712006748',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356886077572,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 5,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_5.png?v=1712006748',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356886110340,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 6,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard_2.png?v=1712006748',
#     'width': 2400,
#     'height': 2400},
#    {'id': 34356886143108,
#     'created_at': '2024-04-01T22:25:48+01:00',
#     'position': 7,
#     'updated_at': '2024-04-01T22:25:48+01:00',
#     'product_id': 7208148664452,
#     'variant_ids': [],
#     'src': 'https://cdn.shopify.com/s/files/1/0074/1307/1990/files/A10660_Tree_Runner_Mens_Rugged_Green_Blizzard.png?v=1712006748',
#     'width': 2400,
#     'height': 2400}],
#   'options': [{'name': 'Size',
#     'position': 1,
#     'values': ['UK 7', 'UK 8', 'UK 9', 'UK 10', 'UK 11', 'UK 12', 'UK 13']}]}]

# %%
keys = [key for dictionary in data for key in dictionary.keys()]

# %%
keys
# Out:
# ['id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options',
#  'id',
#  'title',
#  'handle',
#  'body_html',
#  'published_at',
#  'created_at',
#  'updated_at',
#  'vendor',
#  'product_type',
#  'tags',
#  'variants',
#  'images',
#  'options']

# %%
len(keys)
# Out:
# 390
